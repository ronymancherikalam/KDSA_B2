# %%
# calling neccesary libraries and importing excel file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data= pd.read_excel('Telco-Customer-Churn.xlsx')

# %% [markdown]
# Viewing Data is imported Correctly or not

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# All data is imported successfully

# %% [markdown]
# # Qn1 Compare churn count with respect to gender

# %%
churn_gen=data

# %% [markdown]
# Since churn is qualitative variable converting to quantitative

# %%
#churn_gen['Churn'] = churn_gen['Churn'].astype('category').cat.codes

# %%
churn_gen
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# Extracting column count of churn by gender
churn = data[['Churn','gender']].value_counts(normalize=False)
fig = plt.figure(figsize=(8, 6)) 
# create a bar plot showing the count of churn by Gender
churn.plot(kind='bar',color=['green','green','red','red'],width=.95)
plt.title('Gender wise Churn')
plt.grid()

# %% [markdown]
# # Qn 2 Findout how many female senior citizen there in the dataset

# %%
data.groupby('gender').sum()
# Out:
#         SeniorCitizen  tenure  MonthlyCharges
# gender
# Female            568  112469        227432.4
# Male              574  115521        228684.2

# %%
data1=data[data['gender']=='Female']
fig = plt.figure(figsize=(6, 6)) 
sns.countplot(x ='gender', hue = "SeniorCitizen", data = data1)
plt.grid()
plt.title('Female Senior Citizen ')
plt.legend(title='Sen.Citizen',labels=['No','Yes'])

# %%
# Female senior citizen count is 568

# %% [markdown]
# # Qn 3 Compare 'tenure' with 'Total Charges'

# %%
ten_chrg=data

# %%
plt.figure(figsize=(8,8))
plt.scatter(ten_chrg['tenure'],ten_chrg['TotalCharges'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/y_/9ns43c9113q4cbs56w31sq080000gn/T/ipykernel_14458/2476957634.py in <module>
#       1 plt.figure(figsize=(8,8))
# ----> 2 plt.scatter(ten_chrg['tenure'],ten_chrg['TotalCharges'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
# So there is some  issue with datatype we need to correct it

# %%
ten_chrg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# TotalCharges is worngly put as onject instead fo float datatype. We need to convert to float

# %%
ten_chrg['TotalCharges']=ten_chrg['TotalCharges'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/y_/9ns43c9113q4cbs56w31sq080000gn/T/ipykernel_14458/3161361509.py in <module>
# ----> 1 ten_chrg['TotalCharges']=ten_chrg['TotalCharges'].astype(float)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
# when converting tthere is some null values or issue in data

# %%
ten_chrg.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# Count               0
# dtype: int64

# %%
# No Null value present as per above. So Checking white spaces

# %%
ten_chrg[ten_chrg['TotalCharges']==' '].sum().any()
# Out:
# True

# %%
# So there are white spaces and we have to remove or correct. Recalculating Totalcharges column as below

# %%
ten_chrg['TotalCharges']=ten_chrg['tenure']*ten_chrg['MonthlyCharges']

# %%
# Checking white space again

# %%
ten_chrg[ten_chrg['TotalCharges']==' '].sum().any()
# Out:
# False

# %%
# Plotting graph after data cleaning

# %%
plt.figure(figsize=(8,8))
plt.scatter(ten_chrg['tenure'],ten_chrg['TotalCharges'],marker='>')
plt.title('Comaprison of Tenure vs TotalCharges')
plt.xlabel('Tenure')
plt.ylabel('TotalCharges')
# Out:
# Text(0, 0.5, 'TotalCharges')

# %%
# Inference: As the tenure is increasing total charges paid is proportionaly increasing as total charge is a 
# multiplier of tenure and MonthlyCharges and hence follow a linear relationship

# %% [markdown]
# # Qn 4 Find out Contract Prefered by Senior Citizen

# %%
# Slicing data  to get data of senior Citizens only

# %%
data1=data[data['SeniorCitizen']==1]

# %%
# checking sliced data

# %%
data1[data1['SeniorCitizen']==0]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn, Count]
# Index: []
#
# [0 rows x 22 columns]

# %%
# So only Senior citizen data is stored in data1

# %%
# Grouping the data based on Contract Prefered

# %%
sencit=data1.groupby(by=['Contract']).sum()

# %%
# Checking Grouping is done correctly or not

# %%
sencit['SeniorCitizen']
# Out:
# Contract
# Month-to-month    807
# One year          190
# Two year          145
# Name: SeniorCitizen, dtype: int64

# %%
plot = sencit.plot.pie(y='SeniorCitizen', figsize=(8, 8),autopct='%1.2f%%',title='Senior Citizen Contract preference',
                       ylabel='',explode=(0.05, 0.05, 0.05),shadow=True, startangle=90)

# %%
# Senior citizen prefer monthly subscription.This can be attributed to their monthly source of income 
# post retirement like pension,savings interest etc

# %% [markdown]
# # Qn 5 Comment your finds on Payment Method?

# %%
pmt=data

# %%
pmt['Count']=1

# %%
#overall payment method
pmt1=pmt.groupby(by='PaymentMethod').sum()
# payment method by sen Citzen
sencit=data1.groupby(by=['PaymentMethod']).sum()
# payment method by gender
# Male
male=pmt[data['gender']=='Male']
male1=male.groupby(by='PaymentMethod').sum()
# Female
female=pmt[data['gender']=='Female']
female1=female.groupby(by='PaymentMethod').sum()

# %%
plot1 = pmt1.plot.pie(y='Count', figsize=(6, 6),autopct='%1.2f%%',title='Overall Payment Preference',ylabel='',
                      explode=[0.05,0.05,0.05,0.05],shadow=True,startangle=90)
plot2 = sencit.plot.pie(y='SeniorCitizen', figsize=(6, 6),autopct='%1.2f%%',title='Sen.Citizen Payment Preference',ylabel='',
                      explode=[0.05,0.05,0.05,0.05],shadow=True,startangle=90)
plot3 = male1.plot.pie(y='Count', figsize=(6, 6),autopct='%1.2f%%',title='Male Payment Preference',ylabel='',
                      explode=[0.05,0.05,0.05,0.05],shadow=True,startangle=90)
plot4 = female1.plot.pie(y='Count', figsize=(6, 6),autopct='%1.2f%%',title='Female Payment Preference',ylabel='',
                      explode=[0.05,0.05,0.05,0.05],shadow=True,startangle=90)

# %%
#Inference: As per sample the most prefered payment method is electronic check
           # Sen Citizen more than 50% prefer Electronic check
           # Male and female has not much difference in their choice of prefered payment
